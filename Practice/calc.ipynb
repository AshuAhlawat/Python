# %%
#imports
import math

# %%
print("             CALCULATOR\n\n")

#main loop
while True:
    #Main Menu
    print("[1]  Arithematic")
    print("[2]  Logrithmic")
    print("[3]  HCF, LCM")
    print("[4]  Exit\n")

    #Asking what type of math to do
    while True:
        try:
            category = int(input("->  "))

            if category in [1,2,3,4]:
                break
            else:
                print("Wrong Input! Enter again ")

        except:
            print("Wrong Input! Enter again ")

    print()

    #basic arithematic code
    if category == 1:
        print("Possible Operations(any amount of numbers, use brackets for clarity)")
        print(" + , - , * , ** , / , //")

        expression = input("\nExpression : ")

    #logrithmic and exponentiating code
    elif category == 2:
        print("Possible Operations(use below format, can apply arithematic operations to them)")
        print(" log(Number, Base), exp(Number)")

        log =lambda x,y : math.log(x,y)
        exp =lambda x : math.exp(x)

        expression = input("\nExpression : ")

    #LCM and HCF code
        lcm =lambda *x : math.lcm(*x)
        hcf =lambda *x : math.gcd(*x)

        expression = input("\nExpression : ")
    
    #exit code
    elif category == 4:
        break
    
    #Output code
    while True:
        try:
            output = float(eval(expression))
            print("           =",output)
            break
        except:
            print("Wrong Input! Try Again")
            break
